# %% [markdown]
# <a href="https://colab.research.google.com/github/MaxVieiraSantiago/Graphs/blob/master/Gr%C3%A1ficos_Exemplos_para_Busca_R%C3%A1pida.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Library
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
import seaborn as sns

# Configuração das cors de Fundo do Gráfico
pio.templates.default = "plotly_white"

# ******************************************************************************
# BOX-PLOT
# ******************************************************************************
# Gráfico - BOX-PLOT ( 01 )
fig = px.box( dados_df, x = 'Campo_Eixo_X_df', 
                        y = 'Campo_Eixo_Y_df', 
                        color = 'Campo_Colorir_df', 
                        title = 'Título do Gráfico', 
                        color_discrete_map = { 'Valor 1':'red',
                                               'Valor 2':'green', 
                                               'Valor 3': 'yellow' } )
fig.show()

# Gráfico - BOX-PLOT ( 02 )
sns.boxplot( dataset['Campo_Numerico'] ).set_title( 'Título Desejado' )

# ******************************************************************************
# SCATTER
# ******************************************************************************
# Gráfico - SCATTER ( 01 )
fig = px.scatter( data_frame = dados_df
                  x          = 'Campo_Eixo_X_df', 
                  y          = 'Campo_Eixo_Y_df',
                  size       = 'Campo_Tamanho_df',
                  trendline  = 'ols', 
                  title      = 'Título do Gráfico')
fig.show()

# Gráfico - SCATTER ( 02 )
x = dados_df[ 'Variavel_X' ] 
y = dados_df[ 'Variavel_y' ]

plt.scatter( x, y )

# Gráfico - SCATTER - PLOTTER ( 03 )
fig, axe = plt.subplots( figsize = (4, 5) )
axe = sns.scatterplot( data      = dados_df, 
                       x         = 'Campo_x',
                       y         = 'Campo_y' )
plt.show()

# Gráfico - SCATTER - MATRIX ( 04 )
# dados.iloc[ :, : 4] -> todas as linhas, todas as colunas (0, 1, 2, 3)
y = dados[ 'Variavel_Dependente' ]
pd.plotting.scatter_matrix( dados.iloc[ :, : 4],
                            figsize = (11, 11),
                            c       = y,
                            marker  = 'o',
                            hist_kwds{ 'bins':20 },
                            s       = 60,
                            alpha   =.8 )
plt.figure()


# ******************************************************************************
# HISTOGRAMA
# ******************************************************************************
# Gráfico - HIST ( 01 )
# Para todos os campos do Dataset

dados_df.hist( figsize( 12, 10 ) )

# Gráfico - HIST ( 02 )
# Para 1 determinado campo do Dataset

linhas = 1
colunas = 6
x_continuas[ 'Variavel_continua_01', 'Variavel_continua_02', 'Variavel_continua_03' ]

fig, ax = plt.subplots( linhas, colunas, figsize=( 22, 6 )  )

ddos_df[ 'Campo_01' == 'Não' ][ x_continuas ].hist( bins=30, 
                                                    color='blue', 
                                                    alpha = 0.5, ax=ax )

# Gráfico - HIST ( 02 )
sns.distplot( dataset['Campo_Numerico'] ).set_title( 'Título Desejado' )


# ******************************************************************************
# COUNTPLOT
# ******************************************************************************
# Gráfico - COUNTPLOT ( 01 )

meu_vermelho = '#CD5C5C'
meu_azul     = '#6495ED'
meu_verde    = '#90EE90'
cols = [ meu_vermelho, meu_azul, meu_verde ]

sns.countplot( data    = dados_df, 
               x       = 'Campo_X', 
               palette = cols)

# ******************************************************************************
# BAR
# ******************************************************************************
# Gráfico - BAR ( 01 )

x = dados_df[ 'Variavel_X' ] 
y = dados_df[ 'Variavel_y' ]

plt.bar( x, y, color = cols )
plt.title( 'Título do Gráfico' )
plt.xlabel( 'Eixo X' )
plt.tlabel( 'Eixo y' )
plt.xticks( x, ( 1, 2, 3, 4 ) )

# ******************************************************************************
# HEATMAP - Matriz de Correlação
# ******************************************************************************
# Gráfico - HEATMAP ( 01 )

dados_cont = [ [ 'Campo_continuo_01', 'Campo_continuo_02', 'Campo_continuo_03', 'Campo_continuo_04' ] ]

sns.heatmap( dados_cont.corr(), 
             annot = True, 
             cmap = "Blues")

# ******************************************************************************
# PAIRPLOT
# ******************************************************************************
# Gráfico - PAIRPLOT ( 01 )

sns.pairplot( dados, 
              hue = 'Campo_Quebra' )

# ******************************************************************************
# LIN
# ******************************************************************************
# Gráfico - LINE ( 01 )

plt.style.use('fivethirtyeight')

plt.figure( figsize=(15,10) )
plt.plot( dados['Date'], dados['Close'] )
